# %% [markdown]
# <a href="https://colab.research.google.com/github/YosuaParhusip/Yosua-Parhusip_Pemerograman-dasar/blob/main/pertemuan%202%20pemerograman%20dasar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Jawaban Latihan 1

tegangan_panel = (18)
arus = (6)
jenis_sel = ('Monocrystalline')

print (tegangan_panel)
print (arus)
print (jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
#Jawaban Latihan 2

nama_komponen = 'Trafo'
impedance = 6.6
daya = 260
status_aktif = True

print (nama_komponen, type (nama_komponen))
print (impedance, type (impedance))
print (daya, type (daya))
print (status_aktif, type (status_aktif))
# Out:
# Trafo <class 'str'>
# 6.6 <class 'float'>
# 260 <class 'int'>
# True <class 'bool'>

# %%
#Jawaban Latihan 3

nama_unit = "PLTS_Nunukan"
jumlah_panel = 240
tegangan_keluaran = 48.5
sedang_beroperasi = True

print (nama_unit, type (nama_unit))
print (jumlah_panel, type (jumlah_panel))
print (tegangan_keluaran, type (tegangan_keluaran))
print (sedang_beroperasi, type (sedang_beroperasi))
# Out:
# PLTS_Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
#Jawaban Latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

#a
print ('tegangan harian ke-1:', tegangan_harian [0])
print ('tegangan harian ke-5:', tegangan_harian [5])

#b
tegangan_harian.append (222.0)
print ("setelah ditambah:", tegangan_harian)

#c
print (len (tegangan_harian))
# Out:
# tegangan harian ke-1: 217.5
# tegangan harian ke-5: 216.9
# setelah ditambah: [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# 7

# %%
#Jawaban Latihan 5

motor_listrik = {'nama': "hitachi", 'daya_kw': 64.5, 'tegangan_V':220, 'rpm': 2500}
print (motor_listrik['nama'])
motor_listrik ['rpm'] = 3000
print (motor_listrik)
# Out:
# hitachi
# {'nama': 'hitachi', 'daya_kw': 64.5, 'tegangan_V': 220, 'rpm': 3000}

# %%
#Jawaban Latihan 6

pembangkit = [
{"PLTU": 'unit-1', "kapasitas_MW": 100, 'status': 'operasi'},
{"PLTA": 'unit-2', "kapasitas_MW": 150, 'status': 'operasi'},
{"PLTS": 'unit-3', "kapasitas_MW": 80,  'status': 'pemeliharaan'},
]

print (pembangkit [1]["PLTA"])
pembangkit [2]["status"] = "operasi"
pembangkit.append({"PLTA": "unit-2", "kapasitas_MW":100, "status": "pemeliharaan"})
print ("\n2.seluruh data pembangkit setelah diperbarui")
for unit in pembangkit:
  print (unit)
# Out:
# unit-2
#
# 2.seluruh data pembangkit setelah diperbarui
# {'PLTU': 'unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}
# {'PLTA': 'unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'PLTS': 'unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}
# {'PLTA': 'unit-2', 'kapasitas_MW': 100, 'status': 'pemeliharaan'}
